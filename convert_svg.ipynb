# %%
from IPython.display import SVG, display
file_path = "/workspace/Drawing2CAD/data/svg_raw/0000/00000007/00000007_Front.svg"
display(SVG(filename=file_path))

# %%
with open(file_path, 'r') as f:
    print(f.read())
# Out:
# <?xml version="1.0" ?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink" baseProfile="full" height="200" version="1.1" viewBox="0 0 200 200" width="200">
# 	<defs/>
# 	<path d="M 100.0,49.923500000000004 C 127.65660000000001,49.923500000000004 150.07649999999998,72.3434 150.07649999999998,100.0 C 150.07649999999998,127.65660000000001 127.65660000000001,150.07649999999998 100.0,150.07649999999998 C 72.3434,150.07649999999998 49.923500000000004,127.65660000000001 49.923500000000004,100.0 C 49.923500000000004,72.3434 72.3434,49.923500000000004 100.0,49.923500000000004" fill="none" fill-rule="evenodd" stroke="#000000" stroke-linecap="round" stroke-linejoin="bevel" stroke-opacity="1" stroke-width="0.75"/>
# </svg>
